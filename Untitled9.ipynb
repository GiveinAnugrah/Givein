# %%
import pandas as pd

# %%
dataset = '/content/car details v4.csv'

# %%
data = pd.read_csv(dataset)

# %%
data
# Out:
#                Make                                  Model    Price  Year  \
# 0             Honda                    Amaze 1.2 VX i-VTEC   505000  2017
# 1     Maruti Suzuki                        Swift DZire VDI   450000  2014
# 2           Hyundai                   i10 Magna 1.2 Kappa2   220000  2011
# 3            Toyota                               Glanza G   799000  2019
# 4            Toyota        Innova 2.4 VX 7 STR [2016-2020]  1950000  2018
# ...             ...                                    ...      ...   ...
# 2054       Mahindra                  XUV500 W8 [2015-2017]   850000  2016
# 2055        Hyundai                           Eon D-Lite +   275000  2014
# 2056           Ford            Figo Duratec Petrol ZXI 1.2   240000  2013
# 2057            BMW  5-Series 520d Luxury Line [2017-2019]  4290000  2018
# 2058       Mahindra      Bolero Power Plus ZLX [2016-2019]   670000  2017
#
#       Kilometer Fuel Type Transmission    Location   Color   Owner  \
# ...

# %%
data.head(5)
# Out:
#             Make                            Model    Price  Year  Kilometer  \
# 0          Honda              Amaze 1.2 VX i-VTEC   505000  2017      87150
# 1  Maruti Suzuki                  Swift DZire VDI   450000  2014      75000
# 2        Hyundai             i10 Magna 1.2 Kappa2   220000  2011      67000
# 3         Toyota                         Glanza G   799000  2019      37500
# 4         Toyota  Innova 2.4 VX 7 STR [2016-2020]  1950000  2018      69000
#
#   Fuel Type Transmission   Location   Color   Owner Seller Type   Engine  \
# 0    Petrol       Manual       Pune    Grey   First   Corporate  1198 cc
# 1    Diesel       Manual   Ludhiana   White  Second  Individual  1248 cc
# 2    Petrol       Manual    Lucknow  Maroon   First  Individual  1197 cc
# 3    Petrol       Manual  Mangalore     Red   First  Individual  1197 cc
# 4    Diesel       Manual     Mumbai    Grey   First  Individual  2393 cc
#
# ...

# %%
print(data.dtypes)
# Out:
# Make                   object
# Model                  object
# Price                   int64
# Year                    int64
# Kilometer               int64
# Fuel Type              object
# Transmission           object
# Location               object
# Color                  object
# Owner                  object
# Seller Type            object
# Engine                 object
# Max Power              object
# Max Torque             object
# Drivetrain             object
# Length                float64
# Width                 float64
# Height                float64
# Seating Capacity      float64
# Fuel Tank Capacity    float64
# dtype: object

# %%
datanoid = data.drop(data.columns[2],axis=1)

# %%
datanoid
# Out:
#                Make                                  Model  Year  Kilometer  \
# 0             Honda                    Amaze 1.2 VX i-VTEC  2017      87150
# 1     Maruti Suzuki                        Swift DZire VDI  2014      75000
# 2           Hyundai                   i10 Magna 1.2 Kappa2  2011      67000
# 3            Toyota                               Glanza G  2019      37500
# 4            Toyota        Innova 2.4 VX 7 STR [2016-2020]  2018      69000
# ...             ...                                    ...   ...        ...
# 2054       Mahindra                  XUV500 W8 [2015-2017]  2016      90300
# 2055        Hyundai                           Eon D-Lite +  2014      83000
# 2056           Ford            Figo Duratec Petrol ZXI 1.2  2013      73000
# 2057            BMW  5-Series 520d Luxury Line [2017-2019]  2018      60474
# 2058       Mahindra      Bolero Power Plus ZLX [2016-2019]  2017      72000
#
# ...

# %%
data.describe()
# Out:
#               Price         Year     Kilometer       Length        Width  \
# count  2.059000e+03  2059.000000  2.059000e+03  1995.000000  1995.000000
# mean   1.702992e+06  2016.425449  5.422471e+04  4280.860652  1767.991980
# std    2.419881e+06     3.363564  5.736172e+04   442.458507   135.265825
# min    4.900000e+04  1988.000000  0.000000e+00  3099.000000  1475.000000
# 25%    4.849990e+05  2014.000000  2.900000e+04  3985.000000  1695.000000
# 50%    8.250000e+05  2017.000000  5.000000e+04  4370.000000  1770.000000
# 75%    1.925000e+06  2019.000000  7.200000e+04  4629.000000  1831.500000
# max    3.500000e+07  2022.000000  2.000000e+06  5569.000000  2220.000000
#
#             Height  Seating Capacity  Fuel Tank Capacity
# count  1995.000000       1995.000000         1946.000000
# mean   1591.735338          5.306266           52.002210
# std     136.073956          0.822170           15.110198
# min    1165.000000          2.000000           15.000000
# ...

# %%
data.loc[:,"Year":].corr()
# Out:
# <ipython-input-48-94c1caaba043>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.loc[:,"Year":].corr()
#                         Year  Kilometer    Length     Width    Height  \
# Year                1.000000  -0.296547  0.098770  0.195493  0.116102
# Kilometer          -0.296547   1.000000  0.047705  0.017462  0.093592
# Length              0.098770   0.047705  1.000000  0.807054  0.185451
# Width               0.195493   0.017462  0.807054  1.000000  0.296702
# Height              0.116102   0.093592  0.185451  0.296702  1.000000
# Seating Capacity   -0.006366   0.125244  0.295149  0.221689  0.695761
# Fuel Tank Capacity  0.064512   0.055975  0.813010  0.793868  0.400884
#
#                     Seating Capacity  Fuel Tank Capacity
# Year                       -0.006366            0.064512
# ...

# %% [markdown]
# year vs kilometer

# %%
# @title year vs kilometer

from matplotlib import pyplot as plt
data.plot(kind='scatter', x='Year', y='Kilometer', s=42, alpha=.9)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# !pip install kaggle

# %%
import os
from google.colab import files

if not os.path.exists("/root/.kaggle/kaggle.json"):
    uploaded = files.upload()
    for fn in uploaded.keys():
        print('User uploaded file "{name}" with length {length} bytes'.format(
            name=fn, length=len(uploaded[fn])))
    # Pindahkan file kaggle.json ke direktori yang tepat
    # !mkdir -p ~/.kaggle
    # !mv kaggle.json ~/.kaggle/
    # !chmod 600 /root/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-5c4e3e18-80a0-41e1-ad0a-ba8959d15afd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5c4e3e18-80a0-41e1-ad0a-ba8959d15afd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets list -s "Vehicle"
# Out:
# ...
# ref                                                title                                            size  lastUpdated          downloadCount  voteCount  usabilityRating
# -------------------------------------------------  ----------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# nehalbirla/vehicle-dataset-from-cardekho           Vehicle dataset                                 292KB  2023-01-14 19:35:33         137164        954  1.0
# nelgiriyewithana/australian-vehicle-prices         Australian Vehicle Prices                       582KB  2023-11-27 04:51:30           4268        106  1.0
# syedanwarafridi/vehicle-sales-data                 Vehicle Sales Data                               19MB  2024-02-21 20:16:17           4721         78  1.0
# dataturks/vehicle-number-plate-detection           Vehicle Number Plate Detection                   20KB  2018-07-13 11:29:47          15174        252  0.75
# ...

# %%
# !kaggle datasets download -d nehalbirla/vehicle-dataset-from-cardekho
# Out:
# ...
#   0% 0.00/292k [00:00<?, ?B/s]
# 100% 292k/292k [00:00<00:00, 53.0MB/s]

# %%
# !unzip /content/vehicle-dataset-from-cardekho.zip
# Out:
# Archive:  /content/vehicle-dataset-from-cardekho.zip
#   inflating: CAR DETAILS FROM CAR DEKHO.csv
#   inflating: Car details v3.csv
#   inflating: car data.csv
# replace car details v4.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
pd.read_csv('/content/CAR DETAILS FROM CAR DEKHO.csv')
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...
